# %% [markdown]
# ### Analysis of plumed simulations: Minimization and Equilibration, SymL

# %%
import matplotlib.pyplot as plt
import sys
import pandas as pd
import numpy as np
from IPython.display import set_matplotlib_formats
import glob
import seaborn as sns

# %%
def plot_potential(file):
    fig, ax = plt.subplots(1,1,figsize = (2.5,2))
    min_ = pd.read_csv(file, sep='\s+',skiprows=24,names=['Time (ps)','Potential (kJ/mol)'])
    plt.plot(min_['Time (ps)'],min_['Potential (kJ/mol)'])
    ax.set_ylabel('Potential (kJ/mol)')
    ax.set_xlabel('Time (ps)')
def plot_temp(file):
    fig, ax = plt.subplots(1,1,figsize = (2.5,2))
    min_ = pd.read_csv(file, sep='\s+',skiprows=24,names=['Time (ps)','Temperature (K)'])
    plt.plot(min_['Time (ps)'],min_['Temperature (K)'])
    ax.set_ylabel('Temperature (K)')
    ax.set_xlabel('Time (ps)')
def plot_dens(file):
    fig, ax = plt.subplots(1,1,figsize = (2.5,2))
    min_ = pd.read_csv(file, sep='\s+',skiprows=24,names=['Time (ps)','Density (kg/m^3)'])
    plt.plot(min_['Time (ps)'],min_['Density (kg/m^3)'])
    ax.set_ylabel('Density (kg/m^3)')
    ax.set_xlabel('Time (ps)')
def plot_pressure(file):
    fig, ax = plt.subplots(1,1,figsize = (2.5,2))
    min_ = pd.read_csv(file, sep='\s+',skiprows=24,names=['Time (ps)','Pressure (bar)'])
    plt.plot(min_['Time (ps)'],min_['Pressure (bar)'])
    ax.set_ylabel('Pressure (bar)')
    ax.set_xlabel('Time (ps)')

# %%
folder_SymL = "/home/x_mallu/mln_lf/EXP-23-BV4094/data_SymL/"
folder_NOD = "/home/x_mallu/mln_lf/EXP-23-BV4094/data_NOD/"

# %%
file=folder_NOD + "03-min/check_minim/*_min_potential.xvg"
file = glob.glob(path)
print(file)
plot_potential( file[0] )
plt.title(str(i))
plt.show()
# Out:
# ['/home/x_mallu/mln_lf/EXP-23-BV4094/data_NOD/03-min/check_minim/NMR_rest_NOD_min_potential.xvg']

# %%
file=folder_SymL +  "03-min/check_minim/*_min_potential.xvg"
file = glob.glob(path)
print(file)
plot_potential( file[0] )
plt.title(str(i))
plt.show()
# Out:
# ['/home/x_mallu/mln_lf/EXP-23-BV4094/data_NOD/03-min/check_minim/NMR_rest_NOD_min_potential.xvg']

# %%
file = glob.glob(folder_NOD +"04-nvt/check_nvt/*_nvt_temperature.xvg")
plot_temp( file[0] )
plt.show()
file = glob.glob(folder_SymL +"04-nvt/check_nvt/*_nvt_temperature.xvg")
plot_temp( file[0] )
plt.show()

# %%
file = glob.glob(folder_NOD + "/05-npt/check_npt/*_density.xvg")
plot_dens( file[0] )
plt.show()
file = glob.glob(folder_SymL + "/05-npt/check_npt/*_density.xvg")
plot_dens( file[0] )
plt.show()

# %%
file = glob.glob(folder_NOD + "/05-npt/check_npt/*_pressure.xvg")
plot_dens( file[0] )
plt.show()
file = glob.glob(folder_SymL + "/05-npt/check_npt/*_pressure.xvg")
plot_dens( file[0] )
plt.show()
